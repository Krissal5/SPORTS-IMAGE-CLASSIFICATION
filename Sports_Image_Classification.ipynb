# %%
from zipfile import ZipFile

with ZipFile("Volume.zip", "r") as zip_ref:
    zip_ref.extractall()

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'valid',
#  'train',
#  'test',
#  'EfficientNetB0-100-(224 X 224)- 98.40.h5',
#  'sports.csv',
#  'Volume.zip',
#  'sample_data']

# %%
train_dir = "train"
os.listdir(train_dir)
# Out:
# ['arm wrestling',
#  'cheerleading',
#  'horse jumping',
#  'horseshoe pitching',
#  'sumo wrestling',
#  'jai alai',
#  'ski jumping',
#  'croquet',
#  'gaga',
#  'polo',
#  'figure skating pairs',
#  'steer wrestling',
#  'sidecar racing',
#  'giant slalom',
#  'air hockey',
#  'weightlifting',
#  'hydroplane racing',
#  'rock climbing',
#  'bungee jumping',
#  'hang gliding',
#  'bobsled',
#  'hammer throw',
#  'olympic wrestling',
#  'pole vault',
#  'bike polo',
#  'rugby',
#  'uneven bars',
#  'pole climbing',
#  'frisbee',
#  'figure skating men',
#  'mushing',
#  'water cycling',
#  'bmx',
#  'bowling',
#  'nascar racing',
#  'high jump',
#  'fencing',
#  'wheelchair basketball',
#  'tennis',
#  'shuffleboard',
#  'canoe slamon',
#  'golf',
#  'barell racing',
#  'boxing',
#  'lacrosse',
#  'chuckwagon racing',
#  'surfing',
#  'wheelchair racing',
#  'figure skating women',
#  'jousting',
#  'track bicycle',
#  'ultimate',
#  'wingsuit flying',
#  'roller derby',
# ...

# %%
num_classes = len(os.listdir(train_dir))
num_classes
# Out:
# 100

# %%
class_counts = {}

for cls in os.listdir(train_dir):
    class_path = os.path.join(train_dir, cls)
    if os.path.isdir(class_path):
        class_counts[cls] = len(os.listdir(class_path))

class_counts
# Out:
# {'arm wrestling': 99,
#  'cheerleading': 131,
#  'horse jumping': 134,
#  'horseshoe pitching': 102,
#  'sumo wrestling': 133,
#  'jai alai': 132,
#  'ski jumping': 130,
#  'croquet': 134,
#  'gaga': 118,
#  'polo': 157,
#  'figure skating pairs': 151,
#  'steer wrestling': 122,
#  'sidecar racing': 133,
#  'giant slalom': 150,
#  'air hockey': 112,
#  'weightlifting': 134,
#  'hydroplane racing': 108,
#  'rock climbing': 141,
#  'bungee jumping': 125,
#  'hang gliding': 121,
#  'bobsled': 138,
#  'hammer throw': 122,
#  'olympic wrestling': 167,
#  'pole vault': 138,
#  'bike polo': 110,
#  'rugby': 166,
#  'uneven bars': 156,
#  'pole climbing': 118,
#  'frisbee': 131,
#  'figure skating men': 128,
#  'mushing': 111,
#  'water cycling': 103,
#  'bmx': 140,
#  'bowling': 120,
#  'nascar racing': 189,
#  'high jump': 159,
#  'fencing': 135,
#  'wheelchair basketball': 106,
#  'tennis': 131,
#  'shuffleboard': 130,
#  'canoe slamon': 164,
#  'golf': 157,
#  'barell racing': 123,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.bar(class_counts.keys(), class_counts.values())
plt.xticks(rotation=90)
plt.title("Images per Class (Training Set)")
plt.ylabel("Number of Images")
plt.show()

# %%
os.listdir("test")
# Out:
# ['arm wrestling',
#  'cheerleading',
#  'horse jumping',
#  'horseshoe pitching',
#  'sumo wrestling',
#  'jai alai',
#  'ski jumping',
#  'croquet',
#  'gaga',
#  'polo',
#  'figure skating pairs',
#  'steer wrestling',
#  'sidecar racing',
#  'giant slalom',
#  'air hockey',
#  'weightlifting',
#  'hydroplane racing',
#  'rock climbing',
#  'bungee jumping',
#  'hang gliding',
#  'bobsled',
#  'hammer throw',
#  'olympic wrestling',
#  'pole vault',
#  'bike polo',
#  'rugby',
#  'uneven bars',
#  'pole climbing',
#  'frisbee',
#  'figure skating men',
#  'mushing',
#  'water cycling',
#  'bmx',
#  'bowling',
#  'nascar racing',
#  'high jump',
#  'fencing',
#  'wheelchair basketball',
#  'tennis',
#  'shuffleboard',
#  'canoe slamon',
#  'golf',
#  'barell racing',
#  'boxing',
#  'lacrosse',
#  'chuckwagon racing',
#  'surfing',
#  'wheelchair racing',
#  'figure skating women',
#  'jousting',
#  'track bicycle',
#  'ultimate',
#  'wingsuit flying',
#  'roller derby',
# ...

# %%
os.listdir("valid")
# Out:
# ['arm wrestling',
#  'cheerleading',
#  'horse jumping',
#  'horseshoe pitching',
#  'sumo wrestling',
#  'jai alai',
#  'ski jumping',
#  'croquet',
#  'gaga',
#  'polo',
#  'figure skating pairs',
#  'steer wrestling',
#  'sidecar racing',
#  'giant slalom',
#  'air hockey',
#  'weightlifting',
#  'hydroplane racing',
#  'rock climbing',
#  'bungee jumping',
#  'hang gliding',
#  'bobsled',
#  'hammer throw',
#  'olympic wrestling',
#  'pole vault',
#  'bike polo',
#  'rugby',
#  'uneven bars',
#  'pole climbing',
#  'frisbee',
#  'figure skating men',
#  'mushing',
#  'water cycling',
#  'bmx',
#  'bowling',
#  'nascar racing',
#  'high jump',
#  'fencing',
#  'wheelchair basketball',
#  'tennis',
#  'shuffleboard',
#  'canoe slamon',
#  'golf',
#  'barell racing',
#  'boxing',
#  'lacrosse',
#  'chuckwagon racing',
#  'surfing',
#  'wheelchair racing',
#  'figure skating women',
#  'jousting',
#  'track bicycle',
#  'ultimate',
#  'wingsuit flying',
#  'roller derby',
# ...

# %%
import os

train_dir = "train"
valid_dir = "valid"
test_dir  = "test"

classes = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
num_classes = len(classes)

print("Number of classes:", num_classes)
print("Class names:", classes)

# Count images per class (training set)
class_counts = {}
for cls in classes:
    class_path = os.path.join(train_dir, cls)
    class_counts[cls] = len(os.listdir(class_path))

print("\nImages per class (training):")
for k, v in class_counts.items():
    print(f"{k}: {v}")

# Verify class consistency across splits
valid_classes = [d for d in os.listdir(valid_dir) if os.path.isdir(os.path.join(valid_dir, d))]
test_classes  = [d for d in os.listdir(test_dir) if os.path.isdir(os.path.join(test_dir, d))]

print("\nTrain–Valid class match:", set(classes) == set(valid_classes))
print("Train–Test class match:", set(classes) == set(test_classes))
# Out:
# Number of classes: 100
# ...

# %%
import sys
print("Python version:", sys.version)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0

print("TensorFlow version:", tf.__version__)
# Out:
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# TensorFlow version: 2.19.0

# %%
# Check GPU availability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("✅ GPU is available:", gpus)
else:
    print("❌ GPU NOT available.")

tf.random.set_seed(42)
np.random.seed(42)
# Out:
# ❌ GPU NOT available.

# %%
BASE_DIR = "/content"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VALID_DIR = os.path.join(BASE_DIR, "valid")
TEST_DIR  = os.path.join(BASE_DIR, "test")
CSV_PATH  = os.path.join(BASE_DIR, "sports.csv")

# Load CSV
df = pd.read_csv(CSV_PATH)

print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns)

df.head()
# Out:
# Dataset shape: (14493, 4)
#
# Columns:
# Index(['class id', 'filepaths', 'labels', 'data set'], dtype='object')
#    class id                 filepaths      labels data set
# 0         0  train/air hockey/001.jpg  air hockey    train
# 1         0  train/air hockey/002.jpg  air hockey    train
# 2         0  train/air hockey/003.jpg  air hockey    train
# 3         0  train/air hockey/004.jpg  air hockey    train
# 4         0  train/air hockey/005.jpg  air hockey    train

# %%
classes = df['labels'].unique()
print("Number of classes:", len(classes))
print("Classes:\n", classes)

# Class distribution
df['labels'].value_counts()
# Out:
# Number of classes: 100
# Classes:
#  ['air hockey' 'ampute football' 'archery' 'arm wrestling' 'axe throwing'
#  'balance beam' 'barell racing' 'baseball' 'basketball' 'baton twirling'
#  'bike polo' 'billiards' 'bmx' 'bobsled' 'bowling' 'boxing' 'bull riding'
#  'bungee jumping' 'canoe slamon' 'cheerleading' 'chuckwagon racing'
#  'cricket' 'croquet' 'curling' 'disc golf' 'fencing' 'field hockey'
#  'figure skating men' 'figure skating pairs' 'figure skating women'
#  'fly fishing' 'football' 'formula 1 racing' 'frisbee' 'gaga'
#  'giant slalom' 'golf' 'hammer throw' 'hang gliding' 'harness racing'
#  'high jump' 'hockey' 'horse jumping' 'horse racing' 'horseshoe pitching'
#  'hurdles' 'hydroplane racing' 'ice climbing' 'ice yachting' 'jai alai'
#  'javelin' 'jousting' 'judo' 'lacrosse' 'log rolling' 'luge'
#  'motorcycle racing' 'mushing' 'nascar racing' 'olympic wrestling'
#  'parallel bar' 'pole climbing' 'pole dancing' 'pole vault' 'polo'
# ...

# %%
print(df.columns)

df.head()
# Out:
# Index(['class id', 'filepaths', 'labels', 'data set'], dtype='object')
#    class id                 filepaths      labels data set
# 0         0  train/air hockey/001.jpg  air hockey    train
# 1         0  train/air hockey/002.jpg  air hockey    train
# 2         0  train/air hockey/003.jpg  air hockey    train
# 3         0  train/air hockey/004.jpg  air hockey    train
# 4         0  train/air hockey/005.jpg  air hockey    train

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True
)

valid_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Train generator
train_generator = train_datagen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Validation generator
valid_generator = valid_test_datagen.flow_from_directory(
    directory=VALID_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Test generator
test_generator = valid_test_datagen.flow_from_directory(
    directory=TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("Class indices mapping:")
print(train_generator.class_indices)
# Out:
# Found 13492 images belonging to 100 classes.
# Found 500 images belonging to 100 classes.
# Found 500 images belonging to 100 classes.
# Class indices mapping:
# ...

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

NUM_CLASSES = train_generator.num_classes
print("Number of classes:", NUM_CLASSES)

# Load pre-trained EfficientNetB0
base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze base model layers
base_model.trainable = False

# Custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Final model
model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Number of classes: 100
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ...

# %%
EPOCHS = 10

history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=EPOCHS
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1239s 3s/step - accuracy: 0.4191 - loss: 2.6770 - val_accuracy: 0.8980 - val_loss: 0.4471
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1237s 3s/step - accuracy: 0.8335 - loss: 0.6084 - val_accuracy: 0.9220 - val_loss: 0.2942
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1217s 3s/step - accuracy: 0.8738 - loss: 0.4329 - val_accuracy: 0.9380 - val_loss: 0.2305
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1194s 3s/step - accuracy: 0.8918 - loss: 0.3681 - val_accuracy: 0.9380 - val_loss: 0.2280
# Epoch 5/10
# ...

# %%
model.save("sports_classifier_efficientnetb0.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_accuracy = model.evaluate(test_generator)

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9639 - loss: 0.0937
# Test Accuracy: 0.9620
# Test Loss: 0.1099

# %%
import numpy as np

test_generator.reset()

pred_probs = model.predict(test_generator)
pred_classes = np.argmax(pred_probs, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step

# %%
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(true_classes, pred_classes)
print("Confusion Matrix:\n", cm)

print("\nClassification Report:\n")
print(classification_report(true_classes, pred_classes, target_names=class_labels))
# Out:
# Confusion Matrix:
#  [[5 0 0 ... 0 0 0]
#  [0 5 0 ... 0 0 0]
#  [0 0 5 ... 0 0 0]
#  ...
#  [0 0 0 ... 5 0 0]
#  [0 0 0 ... 0 5 0]
#  [0 0 0 ... 0 0 5]]
#
# Classification Report:
#
#                        precision    recall  f1-score   support
#
#            air hockey       1.00      1.00      1.00         5
#       ampute football       1.00      1.00      1.00         5
#               archery       0.83      1.00      0.91         5
#         arm wrestling       1.00      1.00      1.00         5
#          axe throwing       0.83      1.00      0.91         5
#          balance beam       1.00      1.00      1.00         5
#         barell racing       1.00      1.00      1.00         5
#              baseball       1.00      0.80      0.89         5
#            basketball       0.83      1.00      0.91         5
#        baton twirling       1.00      1.00      1.00         5
#             bike polo       1.00      1.00      1.00         5
# ...

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy Curve')

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss Curve')

plt.show()

# %% [markdown]
# ## Interpretation & Insights
#
# 1️⃣ Model Performance
#
# The transfer learning model (EfficientNetB0) achieved strong performance on unseen test data.
#
# The gap between training accuracy and validation accuracy was reasonable, indicating good generalization.
#
# Test accuracy confirms that the model is not memorizing but learning meaningful visual patterns.
#
# 2️⃣ Class-wise Behavior
#
# From the confusion matrix & classification report:
#
# Most predictions lie along the diagonal, meaning correct classifications.
#
# Some visually similar sports (e.g., similar background or player posture) show minor confusion, which is expected.
#
# Precision and recall values show the model is balanced, not biased toward a single class.
#
# 3️⃣ Overfitting / Underfitting Check
#
# Training and validation curves follow a similar trend.
#
# No sharp divergence → overfitting is minimal.
#
# Data augmentation helped improve robustness.
#
# 4️⃣ Why Transfer Learning Worked Well
#
# EfficientNetB0 already understands edges, textures, shapes, and object patterns.
#
# Only the top layers were trained → faster training, better accuracy, even with limited data.

# %% [markdown]
# 📌 Project Summary
#
# This project demonstrates a multi-class image classification system using transfer learning. A pre-trained EfficientNetB0 model was fine-tuned to classify different sports categories using a structured image dataset.
#
# 📌 Best Model
#
# EfficientNetB0 (Transfer Learning)
#
# Frozen base layers + custom classification head
#
# Optimizer: Adam
#
# Loss: Categorical Cross-Entropy
#
# 📌 Key Learnings
#
# Folder-based datasets are ideal for CNN pipelines.
#
# Transfer learning significantly reduces training time.
#
# Data augmentation improves generalization.
#
# Proper evaluation (confusion matrix, precision, recall) is critical.
#
# 📌 Real-World Applications
#
# Sports analytics
#
# Automated video tagging
#
# Content recommendation systems
#
# Surveillance and activity recognition
#
# Media and broadcasting platforms
#
# 📌 Possible Improvements
#
# Fine-tune deeper layers of EfficientNet
#
# Increase dataset size
#
# Try other architectures (ResNet50, MobileNetV2)
#
# Apply learning-rate scheduling
